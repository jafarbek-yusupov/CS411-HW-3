# %%
from kanren import *

# %% [markdown]
# # Task 1 - family tree puzzle

# %%
# TODO: facts

# NOTE: Use the sample dataset below to express the facts and rules in this task
#       -> Sample Dataset: Windsor Family tree
#       -> https://drive.google.com/file/d/1pMX1W4rCszMbgY7iYxNeU11O-s_FrnoC/view?usp=sharing

# %%
def are_siblings(x, y):
  # TODO: YOUR CODE HERE
  pass


def are_sisters(x, y):
  # TODO: YOUR CODE HERE
  pass


def are_brothers(x, y):
  # TODO: YOUR CODE HERE
  pass


def is_mother_of(x, y):
  # TODO: YOUR CODE HERE
  pass


def is_father_of(x, y):
  # TODO: YOUR CODE HERE
  pass


def is_grandmother_of(x, y):
  # TODO: YOUR CODE HERE
  pass


def is_grandfather_of(x, y):
  # TODO: YOUR CODE HERE
  pass


def are_cousins(x, y):
  # TODO: YOUR CODE HERE
  pass

# %%
kb = lall(
  # TODO: YOUR CODE HERE
)

# %%
# Are A and B cousins?
solution = run(0, ___, kb)
print(___)

# Are A and B sisters?

# Who is the grandmother of B?

# %% [markdown]
# # Task 2 - knights and knaves puzzle

# %% [markdown]
# **Description of the puzzle (in English):**
#
# Premise:
# - On an island, knights always tell the truth, and knaves always lie.
# - You meet three inhabitants: John, David and Michael.
#
# You have the following information:
# - John says: "David is a knave."
# - David says: "I know that John is a knight and that Michael is a knave."
# - Michael says: "I and David are different."
#
# Questions:
# - Who is knave?
# - Who is knight?

# %% [markdown]
# ## Your solution: express the facts, rules, and query

# %%
john, david, michael = vars(3)

# %%
kb = lall(
  # TODO: YOUR CODE HERE
)

# %%
solutions = run(0, (john, david, michael), kb)
john, david, michael = solutions[0]

print('John is a', john)
print('David is a', david)
print('Michael is a', michael)
# Out:
# John is a knight
# David is a knave
# Michael is a knight
